# %%
# for mathemaical operations
import numpy as np
# for dataframe manipulations
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('Airbnb Dataset 19.csv')
data.shape
# Out:
# (249, 16)

# %%
data
# Out:
#         id                                              name  host_id  \
# 0     2539                Clean & quiet apt home by the park     2787
# 1     2595                             Skylit Midtown Castle     2845
# 2     3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3     3831                   Cozy Entire Floor of Brownstone     4869
# 4     5022  Entire Apt: Spacious Studio/Loft by central park     7192
# ..     ...                                               ...      ...
# 244  61492          Exclusive Room with Private Bath in  LES   297769
# 245  61509               Quiet, clean midtown apt w. elevato    23619
# 246  62095                 BK Sweet Suite w/Kitchen&FullBath   281764
# 247  62427               Great East Village Apartment Rental   303882
# 248  62430                     BROWNSTONE SUNDRENCHED BEAUTY   197755
#
#         host_name neighbourhood_group  neighbourhood  latitude  longitude  \
# ...

# %% [markdown]
# A scaterplot to compare price across minimum number of night, we see that price less tha 300 has more data with nights spend between range 1 to 20.

# %%
sns.scatterplot(data=data, x="price", y="minimum_nights")
# Out:
# <Axes: xlabel='price', ylabel='minimum_nights'>

# %% [markdown]
# Scatter plot os used to observe data across number of reviews and price. We see low prices have more reviews and lowest review at highest price 800.

# %%
sns.scatterplot(data=data, x="price", y="number_of_reviews")
# Out:
# <Axes: xlabel='price', ylabel='number_of_reviews'>

# %% [markdown]
# Acoloured palatte distribution plot to see distribution of neighbourhoods across all data.

# %%
#sns.displot(data=data, x="neighbourhood")

sns.displot(data=data, x="neighbourhood", hue="neighbourhood", multiple="stack")

# %% [markdown]
# A line plot to see variance between number of minimum night stays at airbnb. Near about 53counts we see there are more than 175minghts spent and 250 are more than 200.

# %%
sns.lineplot(data=data['minimum_nights'])
# Out:
# <Axes: ylabel='minimum_nights'>

# %%
common= data.groupby('neighbourhood')
common.first()
mean_price = common['price'].mean()
mean_price
top10n= data['neighbourhood'].value_counts().head(5)
top10n.head()
top5 = ['Williamsburg','Harlem','East Village','Bedford-Stuyvesant',"Hell's Kitchen",]

# %%
rslt_df = data[data['neighbourhood'].isin(top5)]
rslt_df
# Out:
#         id                                 name  host_id      host_name  \
# 2     3647  THE VILLAGE OF HARLEM....NEW YORK !     4632      Elisabeth
# 6     5121                      BlissArtsSpace!     7356          Garon
# 7     5178     Large Furnished Room Near B'way      8967       Shunichi
# 11    5441      Central Manhattan/near Broadway     7989           Kate
# 15    6848     Only 2 stops to Manhattan studio    15991  Allen & Irina
# ..     ...                                  ...      ...            ...
# 236  60666     City Room - Private Luxury Suite   256161          Wayne
# 237  60673   Private Room/bath Luxurious Harlem   249372        Cynthia
# 238  60680          The gem of the East Village   292630           Mich
# 243  61406         Great room in great location   297176       Bethania
# 247  62427  Great East Village Apartment Rental   303882           Brie
#
#     neighbourhood_group       neighbourhood  latitude  longitude  \
# ...

# %% [markdown]
# A count plot visualisation of top 5 counting neighbourhoods to compared among each other. We observe Williamburg is has more booking compared to all others.

# %%
sns.countplot(data=rslt_df, x='neighbourhood')
# Out:
# <Axes: xlabel='neighbourhood', ylabel='count'>
